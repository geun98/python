# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family = font_name)
else:
    print('Unknown system... sorry~')

# %%
df1 = pd.read_csv('../data1/grdp (1).csv', encoding = 'euc-kr')
df2 = pd.read_csv('../data1/grdp (2).csv', encoding = 'euc-kr')
df3 = pd.read_csv('../data1/grdp (3).csv', encoding = 'euc-kr')
df4 = pd.read_csv('../data1/grdp (4).csv', encoding = 'euc-kr')
df5 = pd.read_csv('../data1/grdp (5).csv', encoding = 'euc-kr')
df6 = pd.read_csv('../data1/grdp (6).csv', encoding = 'euc-kr')
df7 = pd.read_csv('../data1/grdp (7).csv', encoding = 'euc-kr')
df8 = pd.read_csv('../data1/grdp (8).csv', encoding = 'euc-kr')
df9 = pd.read_csv('../data1/grdp (9).csv', encoding = 'euc-kr')
df10 = pd.read_csv('../data1/grdp (10).csv', encoding = 'euc-kr')
df11 = pd.read_csv('../data1/grdp (11).csv', encoding = 'euc-kr')
df12 = pd.read_csv('../data1/grdp (12).csv', encoding = 'euc-kr')
df13 = pd.read_csv('../data1/grdp (13).csv', encoding = 'euc-kr')
df14 = pd.read_csv('../data1/grdp (14).csv', encoding = 'euc-kr')
df15 = pd.read_csv('../data1/grdp (15).csv', encoding = 'euc-kr')
df16 = pd.read_csv('../data1/grdp (16).csv', encoding = 'euc-kr')

# %%
grdp = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, 
                  df9, df10, df11, df12, df13, df14, df15, df16], ignore_index=True)
grdp
grdp.to_csv('../data1/result.csv',encoding = 'euc-kr')

# %%
grdp
# Out:
#        시점     시군구별         경제활동별      당해년가격    시도별
# 0    2017     충청남도  지역내총생산(시장가격)  115557697   충청남도
# 1    2017      천안시  지역내총생산(시장가격)   26008917   충청남도
# 2    2017      공주시  지역내총생산(시장가격)    3613380   충청남도
# 3    2017      보령시  지역내총생산(시장가격)    4248901   충청남도
# 4    2017      아산시  지역내총생산(시장가격)   30788562   충청남도
# ..    ...      ...           ...        ...    ...
# 703  2018      제주시  지역내총생산(시장가격)   14343720  제주특별시
# 704  2018     서귀포시  지역내총생산(시장가격)    5707401  제주특별시
# 705  2019  제주특별자치도  지역내총생산(시장가격)   20308737  제주특별시
# 706  2019      제주시  지역내총생산(시장가격)   14859505  제주특별시
# 707  2019     서귀포시  지역내총생산(시장가격)    5449232  제주특별시
#
# [708 rows x 5 columns]

# %%
depression = pd.read_csv('../data1/depression.csv', encoding = 'euc-kr')
depression
# Out:
#        시점  시군구별(1)  시군구별  응답자수 (명)  조율 (%)  조율표준오차
# 0    2017    서울특별시    소계     22854     3.6     0.1
# 1    2017    서울특별시   강남구       915     5.0     0.8
# 2    2017    서울특별시   강동구       916     4.9     0.8
# 3    2017    서울특별시   강북구       919     3.4     0.7
# 4    2017    서울특별시   강서구       920     4.7     0.8
# ..    ...      ...   ...       ...     ...     ...
# 979  2020     경상남도   함양군       886     3.9     0.8
# 980  2020     경상남도   합천군       889     1.3     0.4
# 981  2020  제주특별자치도    소계      4979     2.0     0.3
# 982  2020  제주특별자치도  서귀포시      2493     2.3     0.4
# 983  2020  제주특별자치도   제주시      2486     1.9     0.3
#
# [984 rows x 6 columns]

# %%
depression['유병자 수'] = round(depression['조율 (%)'] * depression['응답자수 (명)'] / 100)
depression.head(500)
# Out:
#        시점 시군구별(1) 시군구별  응답자수 (명)  조율 (%)  조율표준오차  유병자 수
# 0    2017   서울특별시   소계     22854     3.6     0.1  823.0
# 1    2017   서울특별시  강남구       915     5.0     0.8   46.0
# 2    2017   서울특별시  강동구       916     4.9     0.8   45.0
# 3    2017   서울특별시  강북구       919     3.4     0.7   31.0
# 4    2017   서울특별시  강서구       920     4.7     0.8   43.0
# ..    ...     ...  ...       ...     ...     ...    ...
# 495  2019   서울특별시  강북구       910     2.6     0.5   24.0
# 496  2019   서울특별시  강서구       907     2.8     0.6   25.0
# 497  2019   서울특별시  관악구       915     5.3     0.6   48.0
# 498  2019   서울특별시  광진구       917     2.3     0.5   21.0
# 499  2019   서울특별시  구로구       905     5.1     0.8   46.0
#
# [500 rows x 7 columns]

# %%
depression.rename(columns = {depression.columns[2] : '시군구별'}, inplace = True)
depression.rename(columns = {depression.columns[1] : '시도별'}, inplace = True)
depression.rename(columns = {depression.columns[6] : 'patient'}, inplace = True)
depression
# Out:
#        시점      시도별  시군구별  응답자수 (명)  조율 (%)  조율표준오차  patient
# 0    2017    서울특별시    소계     22854     3.6     0.1    823.0
# 1    2017    서울특별시   강남구       915     5.0     0.8     46.0
# 2    2017    서울특별시   강동구       916     4.9     0.8     45.0
# 3    2017    서울특별시   강북구       919     3.4     0.7     31.0
# 4    2017    서울특별시   강서구       920     4.7     0.8     43.0
# ..    ...      ...   ...       ...     ...     ...      ...
# 979  2020     경상남도   함양군       886     3.9     0.8     35.0
# 980  2020     경상남도   합천군       889     1.3     0.4     12.0
# 981  2020  제주특별자치도    소계      4979     2.0     0.3    100.0
# 982  2020  제주특별자치도  서귀포시      2493     2.3     0.4     57.0
# 983  2020  제주특별자치도   제주시      2486     1.9     0.3     47.0
#
# [984 rows x 7 columns]

# %%
depression.rename(columns = {depression.columns[6] : 'patient'}, inplace = True)

# %%
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
from statsmodels.stats.anova import anova_lm
from scipy.stats import f_oneway
import seaborn as sns
import platform

# %%
anova = ols('patient ~ 시군구별', depression).fit()
anova_lm(anova)
# Out:
#              df        sum_sq       mean_sq       F        PR(>F)
# 시군구별      207.0  1.033217e+07  49913.873123  5.4297  4.683616e-67
# Residual  776.0  7.133573e+06   9192.749350     NaN           NaN

# %%
result = pd.merge(grdp,depression,on = ['시점','시군구별'])
result
# Out:
#        시점  시군구별         경제활동별     당해년가격  시도별_x    시도별_y  응답자수 (명)  조율 (%)  \
# 0    2017   천안시  지역내총생산(시장가격)  26008917   충청남도     충청남도       902     8.1
# 1    2017   공주시  지역내총생산(시장가격)   3613380   충청남도     충청남도       880     4.1
# 2    2017   보령시  지역내총생산(시장가격)   4248901   충청남도     충청남도       899     8.6
# 3    2017   아산시  지역내총생산(시장가격)  30788562   충청남도     충청남도       893     4.9
# 4    2017   서산시  지역내총생산(시장가격)  17637719   충청남도     충청남도       890     4.6
# ..    ...   ...           ...       ...    ...      ...       ...     ...
# 980  2017  서귀포시  지역내총생산(시장가격)   5936937  제주특별시  제주특별자치도      2436     2.5
# 981  2018   제주시  지역내총생산(시장가격)  14343720  제주특별시  제주특별자치도      2508     2.2
# 982  2018  서귀포시  지역내총생산(시장가격)   5707401  제주특별시  제주특별자치도      2497     2.1
# 983  2019   제주시  지역내총생산(시장가격)  14859505  제주특별시  제주특별자치도      2506     2.5
# 984  2019  서귀포시  지역내총생산(시장가격)   5449232  제주특별시  제주특별자치도      2500     1.3
#
#      조율표준오차  patient
# 0       0.9     73.0
# 1       0.8     36.0
# ...

# %%
result.to_csv('../data1/result.csv',encoding = 'euc-kr')

# %%
result['당해년가격(단위:100억)'] = result['당해년가격'] / 10000
result
# Out:
#        시점  시군구별         경제활동별     당해년가격  시도별_x    시도별_y  응답자수 (명)  조율 (%)  \
# 0    2017   천안시  지역내총생산(시장가격)  26008917   충청남도     충청남도       902     8.1
# 1    2017   공주시  지역내총생산(시장가격)   3613380   충청남도     충청남도       880     4.1
# 2    2017   보령시  지역내총생산(시장가격)   4248901   충청남도     충청남도       899     8.6
# 3    2017   아산시  지역내총생산(시장가격)  30788562   충청남도     충청남도       893     4.9
# 4    2017   서산시  지역내총생산(시장가격)  17637719   충청남도     충청남도       890     4.6
# ..    ...   ...           ...       ...    ...      ...       ...     ...
# 980  2017  서귀포시  지역내총생산(시장가격)   5936937  제주특별시  제주특별자치도      2436     2.5
# 981  2018   제주시  지역내총생산(시장가격)  14343720  제주특별시  제주특별자치도      2508     2.2
# 982  2018  서귀포시  지역내총생산(시장가격)   5707401  제주특별시  제주특별자치도      2497     2.1
# 983  2019   제주시  지역내총생산(시장가격)  14859505  제주특별시  제주특별자치도      2506     2.5
# 984  2019  서귀포시  지역내총생산(시장가격)   5449232  제주특별시  제주특별자치도      2500     1.3
#
#      조율표준오차  patient  당해년가격(단위:100억)
# 0       0.9     73.0       2600.8917
# ...

# %%
fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
 
font_size = 15
plt.scatter(result['당해년가격(단위:100억)'],result['patient'])
plt.xlabel('당해년가격(단위:100억)', fontsize=font_size)
plt.ylabel('patient',fontsize=font_size)
plt.show()

# %%
from statsmodels.stats.anova import anova_lm

# %%
result.rename(columns = {result.columns[9] : 'Patient'}, inplace = True)
result.rename(columns = {result.columns[10] : 'grdp'}, inplace = True)

# %%
fit = ols('Patient ~ grdp',data=result).fit()

# %%
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Patient   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     53.05
# Date:                Wed, 25 May 2022   Prob (F-statistic):           6.66e-13
# Time:                        21:49:53   Log-Likelihood:                -4223.7
# No. Observations:                 985   AIC:                             8451.
# Df Residuals:                     983   BIC:                             8461.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     27.7893      0.721     38.554      0.000      26.375      29.204
# ...

# %%
psychiatry = pd.read_csv('../data1/psychiatry.csv', encoding = 'euc-kr')
psychiatry
# Out:
#       시점      시도별  의료기관1  의료기관2  의료기관3  의료기관4  의료기관5  의료기관6   총합
# 0   2018    서울특별시      1      1      3     40     20    362  427
# 1   2018    부산광역시      0      1     18     21      4     97  141
# 2   2018    대구광역시      0      1      1      8     16     62   88
# 3   2018    인천광역시      0      0      4     15     14     47   80
# 4   2018    광주광역시      0      1      4      8      9     34   56
# 5   2018    대전광역시      0      1      3      8      4     58   74
# 6   2018    울산광역시      0      0      0      3      7     17   27
# 7   2018  세종특별자치시      0      0      1      0      0      7    8
# 8   2018      경기도      0      5     35     32     32    245  349
# 9   2018      강원도      1      0      4     11      5     22   43
# 10  2018     충청북도      0      0      8      7      6     27   48
# 11  2018     충청남도      2      0     14      4      4     32   56
# 12  2018     전라북도      0      1      2      9      7     43   62
# ...

# %%
psychiatry.rename(columns = {psychiatry.columns[1] : '시도별'}, inplace = True)
del psychiatry['의료기관1']
del psychiatry['의료기관2']
del psychiatry['의료기관3']
del psychiatry['의료기관4']
del psychiatry['의료기관5']
del psychiatry['의료기관6']
psychiatry.head(10)
# Out:
#      시점      시도별   총합
# 0  2018    서울특별시  427
# 1  2018    부산광역시  141
# 2  2018    대구광역시   88
# 3  2018    인천광역시   80
# 4  2018    광주광역시   56
# 5  2018    대전광역시   74
# 6  2018    울산광역시   27
# 7  2018  세종특별자치시    8
# 8  2018      경기도  349
# 9  2018      강원도   43

# %%
depression2 = pd.read_csv('../data1/depression2.csv', encoding = 'utf-8')
depression2
# Out:
#        시점 지역구분      시도별     빈도  표준화율
# 0    2008   시도    서울특별시  21916   8.1
# 1    2008   시도    부산광역시  14272   6.8
# 2    2008   시도    대구광역시   6977   7.2
# 3    2008   시도    인천광역시   8284   8.8
# 4    2008   시도    광주광역시   4431   8.7
# ..    ...  ...      ...    ...   ...
# 212  2020   시도     전라북도  12441   4.8
# 213  2020   시도     전라남도  19552   4.2
# 214  2020   시도     경상북도  22163   6.1
# 215  2020   시도     경상남도  17936   6.4
# 216  2020   시도  제주특별자치도   5050   4.3
#
# [217 rows x 5 columns]

# %%
anova = ols('표준화율 ~ 시도별', depression2).fit()
anova_lm(anova)
# Out:
#              df      sum_sq   mean_sq         F        PR(>F)
# 시도별        16.0  120.667508  7.541719  5.339038  2.384164e-09
# Residual  200.0  282.512308  1.412562       NaN           NaN

# %%
from matplotlib import pyplot as plt

x = depression2['시도별']
y = depression2['표준화율']
plt.figure(figsize=(20,5))
plt.bar(x, y, color = '#8CC63F')
plt.show()

# %%
import folium
import googlemaps

# %%
my_key = 'AIzaSyA3CQuOe2_edbplAOpebXQCIQEw6kr2R5E'
gmaps = googlemaps.Client(key=my_key)

# %%
# Out:
# [0        서울특별시
#  1        부산광역시
#  2        대구광역시
#  3        인천광역시
#  4        광주광역시
#          ...
#  212       전라북도
#  213       전라남도
#  214       경상북도
#  215       경상남도
#  216    제주특별자치도
#  Name: 시도별, Length: 217, dtype: object,
#  0        서울특별시
#  1        부산광역시
#  2        대구광역시
#  3        인천광역시
#  4        광주광역시
#          ...
#  212       전라북도
#  213       전라남도
#  214       경상북도
#  215       경상남도
#  216    제주특별자치도
#  Name: 시도별, Length: 217, dtype: object,
#  0        서울특별시
#  1        부산광역시
#  2        대구광역시
#  3        인천광역시
#  4        광주광역시
#          ...
#  212       전라북도
#  213       전라남도
#  214       경상북도
#  215       경상남도
#  216    제주특별자치도
#  Name: 시도별, Length: 217, dtype: object,
#  0        서울특별시
#  1        부산광역시
#  2        대구광역시
#  3        인천광역시
#  4        광주광역시
#          ...
#  212       전라북도
#  213       전라남도
#  214       경상북도
#  215       경상남도
#  216    제주특별자치도
#  Name: 시도별, Length: 217, dtype: object,
#  0        서울특별시
#  1        부산광역시
# ...

# %%
grdp2 = pd.read_csv('../data1/grdp2.csv', encoding = 'euc-kr')
grdp2
# Out:
#        시점      시도별         경제활동별         명목
# 0    2008    서울특별시  지역내총생산(시장가격)  282065734
# 1    2008    부산광역시  지역내총생산(시장가격)   63844756
# 2    2008    대구광역시  지역내총생산(시장가격)   37335462
# 3    2008    인천광역시  지역내총생산(시장가격)   53700045
# 4    2008    광주광역시  지역내총생산(시장가격)   24213929
# ..    ...      ...           ...        ...
# 211  2020     전라북도  지역내총생산(시장가격)   53177897
# 212  2020     전라남도  지역내총생산(시장가격)   78104856
# 213  2020     경상북도  지역내총생산(시장가격)  105249629
# 214  2020     경상남도  지역내총생산(시장가격)  112092547
# 215  2020  제주특별자치도  지역내총생산(시장가격)   19532179
#
# [216 rows x 4 columns]

# %%
result3 = pd.merge(grdp2,depression2,on = ['시점','시도별'])
result3['생산량'] = result3['명목'] / 10000
result3
# Out:
#        시점      시도별         경제활동별         명목 지역구분     빈도  표준화율         생산량
# 0    2008    서울특별시  지역내총생산(시장가격)  282065734   시도  21916   8.1  28206.5734
# 1    2008    부산광역시  지역내총생산(시장가격)   63844756   시도  14272   6.8   6384.4756
# 2    2008    대구광역시  지역내총생산(시장가격)   37335462   시도   6977   7.2   3733.5462
# 3    2008    인천광역시  지역내총생산(시장가격)   53700045   시도   8284   8.8   5370.0045
# 4    2008    광주광역시  지역내총생산(시장가격)   24213929   시도   4431   8.7   2421.3929
# ..    ...      ...           ...        ...  ...    ...   ...         ...
# 203  2020     전라북도  지역내총생산(시장가격)   53177897   시도  12441   4.8   5317.7897
# 204  2020     전라남도  지역내총생산(시장가격)   78104856   시도  19552   4.2   7810.4856
# 205  2020     경상북도  지역내총생산(시장가격)  105249629   시도  22163   6.1  10524.9629
# 206  2020     경상남도  지역내총생산(시장가격)  112092547   시도  17936   6.4  11209.2547
# 207  2020  제주특별자치도  지역내총생산(시장가격)   19532179   시도   5050   4.3   1953.2179
#
# [208 rows x 8 columns]

# %%
result3["Log_X"] = np.log1p(result3["생산량"])
result3["Log_X"]
result3["Log_Y"] = np.log1p(result3["빈도"])
result3["Log_Y"]
# Out:
# 0       9.995018
# 1       9.566125
# 2       8.850518
# 3       9.022202
# 4       8.396606
#          ...
# 203     9.428833
# 204     9.880884
# 205    10.006225
# 206     9.794621
# 207     8.527342
# Name: Log_Y, Length: 208, dtype: float64

# %%
result3.to_csv('../data1/result3.csv',encoding = 'euc-kr')

# %%
plt.scatter(result3['생산량'],result3['빈도'],color = '#8CC63F')
plt.ylabel('빈도')
plt.xlabel('생산량')
plt.show()

# %%
fit2 = ols('빈도 ~ 생산량',data=result3).fit()

# %%
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     빈도   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     312.4
# Date:                Wed, 25 May 2022   Prob (F-statistic):           3.70e-43
# Time:                        21:49:54   Log-Likelihood:                -2097.9
# No. Observations:                 208   AIC:                             4200.
# Df Residuals:                     206   BIC:                             4206.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7570.2248    552.592     13.699      0.000    6480.765    8659.685
# ...

# %%
result4 = pd.merge(psychiatry,depression2,on = ['시점','시도별'])
result4.to_csv('../data1/result4.csv',encoding = 'euc-kr')
result4.head(12)
# Out:
#       시점    시도별   총합 지역구분     빈도  표준화율
# 0   2018  서울특별시  427   시도  22903   4.9
# 1   2018  부산광역시  141   시도  14515   6.0
# 2   2018  대구광역시   88   시도   7302   3.4
# 3   2018  인천광역시   80   시도   8977   8.1
# 4   2018  광주광역시   56   시도   4564   4.5
# 5   2018  대전광역시   74   시도   4575   4.7
# 6   2018  울산광역시   27   시도   4552   4.8
# 7   2018    경기도  349   시도  40943   6.2
# 8   2018    강원도   43   시도  15816   5.3
# 9   2018   충청북도   48   시도  12471   5.7
# 10  2018   충청남도   56   시도  13477   6.8
# 11  2018   전라북도   62   시도  12465   8.7

# %%
plt.scatter(result4['총합'],result4['빈도'],color = '#8CC63F')
plt.ylabel('빈도')
plt.xlabel('총합')
plt.show()

# %%
fit3 = ols('빈도 ~ 총합',data=result4).fit()

# %%
fit3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     빈도   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     38.24
# Date:                Wed, 25 May 2022   Prob (F-statistic):           1.53e-07
# Time:                        21:49:54   Log-Likelihood:                -492.11
# No. Observations:                  48   AIC:                             988.2
# Df Residuals:                      46   BIC:                             992.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8632.2478   1358.766      6.353      0.000    5897.194    1.14e+04
# ...
